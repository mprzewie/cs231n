# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 20 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]
n_bins = [10, 20, 30, 40, 50, 60]
results = {}
best_val = -1
best_svm = None


pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for nb in n_bins:
    num_color_bins = nb # Number of bins in the color histogram
    feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
    X_train_feats = extract_features(X_train, feature_fns, verbose=True)
    X_val_feats = extract_features(X_val, feature_fns)
    X_test_feats = extract_features(X_test, feature_fns)

    # Preprocessing: Subtract the mean feature
    mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
    X_train_feats -= mean_feat
    X_val_feats -= mean_feat
    X_test_feats -= mean_feat

    # Preprocessing: Divide by standard deviation. This ensures that each feature
    # has roughly the same scale.
    std_feat = np.std(X_train_feats, axis=0, keepdims=True)
    X_train_feats /= std_feat
    X_val_feats /= std_feat
    X_test_feats /= std_feat

    # Preprocessing: Add a bias dimension
    X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
    X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
    X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])

    for lr in learning_rates:
        for reg in regularization_strengths:
            svm = LinearSVM()
            svm.train(X_train_feats, y_train, learning_rate=1e-7, reg=2.5e4,
                          num_iters=2000, verbose=True)
            y_train_pred = svm.predict(X_train_feats)
            y_train_acc = np.mean(y_train == y_train_pred)
            print('training accuracy: %f' % y_train_acc)
            y_val_pred = svm.predict(X_val_feats)
            y_val_acc = np.mean(y_val == y_val_pred)
            print('validation accuracy: %f' % y_val_acc)
            results[(lr, reg, nb)] = (y_train_acc, y_val_acc)
            if best_val < y_val_acc:
                best_val = y_val_acc
                best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg, nb in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, nb)]
    print('nb %e lr %e reg %e train accuracy: %f val accuracy: %f' % (
                nb, lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 155)
# iteration 0 / 2000: loss 9.020511
# iteration 100 / 2000: loss 9.005434
# iteration 200 / 2000: loss 8.993787
# iteration 300 / 2000: loss 9.000225
# iteration 400 / 2000: loss 9.006877
# iteration 500 / 2000: loss 9.001923
# iteration 600 / 2000: loss 9.002770
# iteration 700 / 2000: loss 8.998970
# iteration 800 / 2000: loss 8.999034
# iteration 900 / 2000: loss 8.998908
# iteration 1000 / 2000: loss 8.998019
# iteration 1100 / 2000: loss 8.997967
# iteration 1200 / 2000: loss 8.998093
# iteration 1300 / 2000: loss 8.997932
# iteration 1400 / 2000: loss 8.997669
# iteration 1500 / 2000: loss 8.997309
# iteration 1600 / 2000: loss 8.997285
# iteration 1700 / 2000: loss 8.997490
# iteration 1800 / 2000: loss 8.997259
# iteration 1900 / 2000: loss 8.997157
# (49000,)
# training accuracy: 0.373694
# (1000,)
# validation accuracy: 0.388000
# (49000, 155)
# iteration 0 / 2000: loss 9.010234
# iteration 100 / 2000: loss 8.997617
# iteration 200 / 2000: loss 9.006337
# iteration 300 / 2000: loss 8.994485
# iteration 400 / 2000: loss 8.994639
# iteration 500 / 2000: loss 8.998367
# iteration 600 / 2000: loss 8.998960
# iteration 700 / 2000: loss 9.001739
# iteration 800 / 2000: loss 8.997132
# iteration 900 / 2000: loss 8.997049
# iteration 1000 / 2000: loss 8.998056
# iteration 1100 / 2000: loss 8.998496
# iteration 1200 / 2000: loss 8.997250
# iteration 1300 / 2000: loss 8.997130
# iteration 1400 / 2000: loss 8.997500
# iteration 1500 / 2000: loss 8.997495
# iteration 1600 / 2000: loss 8.997437
# iteration 1700 / 2000: loss 8.997246
# iteration 1800 / 2000: loss 8.997288
# iteration 1900 / 2000: loss 8.997301
# (49000,)
# training accuracy: 0.384245
# (1000,)
# validation accuracy: 0.375000
# (49000, 155)
# iteration 0 / 2000: loss 9.001995
# iteration 100 / 2000: loss 8.996034
# iteration 200 / 2000: loss 8.997576
# iteration 300 / 2000: loss 8.999487
# iteration 400 / 2000: loss 9.003591
# iteration 500 / 2000: loss 9.001454
# iteration 600 / 2000: loss 8.996607
# iteration 700 / 2000: loss 8.997899
# iteration 800 / 2000: loss 8.998812
# iteration 900 / 2000: loss 8.998336
# iteration 1000 / 2000: loss 8.998691
# iteration 1100 / 2000: loss 8.997123
# iteration 1200 / 2000: loss 8.997162
# iteration 1300 / 2000: loss 8.998026
# iteration 1400 / 2000: loss 8.997417
# iteration 1500 / 2000: loss 8.997431
# iteration 1600 / 2000: loss 8.997716
# iteration 1700 / 2000: loss 8.997306
# iteration 1800 / 2000: loss 8.997239
# iteration 1900 / 2000: loss 8.997186
# (49000,)
# training accuracy: 0.388959
# (1000,)
# validation accuracy: 0.371000
# (49000, 155)
# iteration 0 / 2000: loss 9.004579
# iteration 100 / 2000: loss 9.007226
# iteration 200 / 2000: loss 9.010798
# iteration 300 / 2000: loss 8.998258
# iteration 400 / 2000: loss 9.002671
# iteration 500 / 2000: loss 8.993381
# iteration 600 / 2000: loss 8.998195
# iteration 700 / 2000: loss 8.997794
# iteration 800 / 2000: loss 8.998702
# iteration 900 / 2000: loss 8.997329
# iteration 1000 / 2000: loss 8.997428
# iteration 1100 / 2000: loss 8.996759
# iteration 1200 / 2000: loss 8.997164
# iteration 1300 / 2000: loss 8.997016
# iteration 1400 / 2000: loss 8.997875
# iteration 1500 / 2000: loss 8.997317
# iteration 1600 / 2000: loss 8.997248
# iteration 1700 / 2000: loss 8.997214
# iteration 1800 / 2000: loss 8.997220
# iteration 1900 / 2000: loss 8.997285
# (49000,)
# training accuracy: 0.389224
# (1000,)
# validation accuracy: 0.394000
# (49000, 155)
# iteration 0 / 2000: loss 9.015465
# iteration 100 / 2000: loss 8.993709
# iteration 200 / 2000: loss 9.000977
# iteration 300 / 2000: loss 8.997563
# iteration 400 / 2000: loss 9.000148
# iteration 500 / 2000: loss 8.999586
# iteration 600 / 2000: loss 9.002325
# iteration 700 / 2000: loss 8.998642
# iteration 800 / 2000: loss 8.998253
# iteration 900 / 2000: loss 8.998103
# iteration 1000 / 2000: loss 8.998066
# iteration 1100 / 2000: loss 8.996682
# iteration 1200 / 2000: loss 8.998286
# iteration 1300 / 2000: loss 8.997796
# iteration 1400 / 2000: loss 8.997428
# iteration 1500 / 2000: loss 8.997615
# iteration 1600 / 2000: loss 8.997631
# iteration 1700 / 2000: loss 8.997146
# iteration 1800 / 2000: loss 8.997419
# iteration 1900 / 2000: loss 8.997631
# (49000,)
# training accuracy: 0.378612
# (1000,)
# validation accuracy: 0.356000
# (49000, 155)
# iteration 0 / 2000: loss 8.996805
# iteration 100 / 2000: loss 8.993737
# iteration 200 / 2000: loss 9.002225
# iteration 300 / 2000: loss 8.999025
# iteration 400 / 2000: loss 8.996301
# iteration 500 / 2000: loss 9.001896
# iteration 600 / 2000: loss 8.998110
# iteration 700 / 2000: loss 8.997956
# iteration 800 / 2000: loss 8.995519
# iteration 900 / 2000: loss 8.994742
# iteration 1000 / 2000: loss 8.996546
# iteration 1100 / 2000: loss 8.997562
# iteration 1200 / 2000: loss 8.997521
# iteration 1300 / 2000: loss 8.997348
# iteration 1400 / 2000: loss 8.996852
# iteration 1500 / 2000: loss 8.997071
# iteration 1600 / 2000: loss 8.997256
# iteration 1700 / 2000: loss 8.997471
# iteration 1800 / 2000: loss 8.996992
# iteration 1900 / 2000: loss 8.996893
# (49000,)
# training accuracy: 0.386939
# (1000,)
# validation accuracy: 0.400000
# (49000, 155)
# iteration 0 / 2000: loss 8.994308
# iteration 100 / 2000: loss 8.999388
# iteration 200 / 2000: loss 8.985858
# iteration 300 / 2000: loss 8.997910
# iteration 400 / 2000: loss 9.001568
# iteration 500 / 2000: loss 8.992329
# iteration 600 / 2000: loss 8.998209
# iteration 700 / 2000: loss 8.997140
# iteration 800 / 2000: loss 8.997628
# iteration 900 / 2000: loss 8.996687
# iteration 1000 / 2000: loss 8.996457
# iteration 1100 / 2000: loss 8.996715
# iteration 1200 / 2000: loss 8.998071
# iteration 1300 / 2000: loss 8.997280
# iteration 1400 / 2000: loss 8.997171
# iteration 1500 / 2000: loss 8.997405
# iteration 1600 / 2000: loss 8.997157
# iteration 1700 / 2000: loss 8.996901
# iteration 1800 / 2000: loss 8.997336
# iteration 1900 / 2000: loss 8.997466
# (49000,)
# training accuracy: 0.390469
# (1000,)
# validation accuracy: 0.387000
# (49000, 155)
# iteration 0 / 2000: loss 8.989967
# iteration 100 / 2000: loss 8.988649
# iteration 200 / 2000: loss 8.989410
# iteration 300 / 2000: loss 8.987317
# iteration 400 / 2000: loss 8.999900
# iteration 500 / 2000: loss 8.994556
# iteration 600 / 2000: loss 8.996804
# iteration 700 / 2000: loss 8.995407
# iteration 800 / 2000: loss 8.996304
# iteration 900 / 2000: loss 8.995761
# iteration 1000 / 2000: loss 8.995848
# iteration 1100 / 2000: loss 8.997091
# iteration 1200 / 2000: loss 8.996271
# iteration 1300 / 2000: loss 8.998027
# iteration 1400 / 2000: loss 8.997038
# iteration 1500 / 2000: loss 8.997131
# iteration 1600 / 2000: loss 8.996948
# iteration 1700 / 2000: loss 8.997140
# iteration 1800 / 2000: loss 8.997237
# iteration 1900 / 2000: loss 8.996951
# (49000,)
# training accuracy: 0.388020
# (1000,)
# validation accuracy: 0.378000
# (49000, 155)
# iteration 0 / 2000: loss 8.992687
# iteration 100 / 2000: loss 8.998955
# iteration 200 / 2000: loss 8.995328
# iteration 300 / 2000: loss 8.997368
# iteration 400 / 2000: loss 8.990259
# iteration 500 / 2000: loss 8.993997
# iteration 600 / 2000: loss 8.997615
# iteration 700 / 2000: loss 8.996216
# iteration 800 / 2000: loss 8.997934
# iteration 900 / 2000: loss 8.996720
# iteration 1000 / 2000: loss 8.996963
# iteration 1100 / 2000: loss 8.997701
# iteration 1200 / 2000: loss 8.997918
# iteration 1300 / 2000: loss 8.996186
# iteration 1400 / 2000: loss 8.997385
# iteration 1500 / 2000: loss 8.996923
# iteration 1600 / 2000: loss 8.996904
# iteration 1700 / 2000: loss 8.997006
# iteration 1800 / 2000: loss 8.997450
# iteration 1900 / 2000: loss 8.996985
# (49000,)
# training accuracy: 0.379510
# (1000,)
# validation accuracy: 0.367000
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 165)
# iteration 0 / 2000: loss 9.016083
# iteration 100 / 2000: loss 8.994588
# iteration 200 / 2000: loss 8.995662
# iteration 300 / 2000: loss 8.994857
# iteration 400 / 2000: loss 8.999533
# iteration 500 / 2000: loss 8.994687
# iteration 600 / 2000: loss 9.001741
# iteration 700 / 2000: loss 8.997592
# iteration 800 / 2000: loss 8.996085
# iteration 900 / 2000: loss 8.998073
# iteration 1000 / 2000: loss 8.996048
# iteration 1100 / 2000: loss 8.996820
# iteration 1200 / 2000: loss 8.997712
# iteration 1300 / 2000: loss 8.997247
# iteration 1400 / 2000: loss 8.997009
# iteration 1500 / 2000: loss 8.996872
# iteration 1600 / 2000: loss 8.996930
# iteration 1700 / 2000: loss 8.996747
# iteration 1800 / 2000: loss 8.997025
# iteration 1900 / 2000: loss 8.997376
# (49000,)
# training accuracy: 0.392204
# (1000,)
# validation accuracy: 0.384000
# (49000, 165)
# iteration 0 / 2000: loss 9.005122
# iteration 100 / 2000: loss 8.993855
# iteration 200 / 2000: loss 8.992762
# iteration 300 / 2000: loss 9.000827
# iteration 400 / 2000: loss 8.999440
# iteration 500 / 2000: loss 8.999824
# iteration 600 / 2000: loss 9.001425
# iteration 700 / 2000: loss 8.999353
# iteration 800 / 2000: loss 8.996063
# iteration 900 / 2000: loss 8.997019
# iteration 1000 / 2000: loss 8.998303
# iteration 1100 / 2000: loss 8.997415
# iteration 1200 / 2000: loss 8.997867
# iteration 1300 / 2000: loss 8.997761
# iteration 1400 / 2000: loss 8.997458
# iteration 1500 / 2000: loss 8.996986
# iteration 1600 / 2000: loss 8.997236
# iteration 1700 / 2000: loss 8.996720
# iteration 1800 / 2000: loss 8.997465
# iteration 1900 / 2000: loss 8.997297
# (49000,)
# training accuracy: 0.391347
# (1000,)
# validation accuracy: 0.390000
# (49000, 165)
# iteration 0 / 2000: loss 8.983931
# iteration 100 / 2000: loss 8.984015
# iteration 200 / 2000: loss 8.996391
# iteration 300 / 2000: loss 9.001473
# iteration 400 / 2000: loss 8.999053
# iteration 500 / 2000: loss 8.997198
# iteration 600 / 2000: loss 8.995370
# iteration 700 / 2000: loss 8.996371
# iteration 800 / 2000: loss 8.999388
# iteration 900 / 2000: loss 8.995625
# iteration 1000 / 2000: loss 8.998350
# iteration 1100 / 2000: loss 8.996542
# iteration 1200 / 2000: loss 8.997358
# iteration 1300 / 2000: loss 8.996894
# iteration 1400 / 2000: loss 8.997130
# iteration 1500 / 2000: loss 8.996876
# iteration 1600 / 2000: loss 8.996984
# iteration 1700 / 2000: loss 8.996916
# iteration 1800 / 2000: loss 8.996916
# iteration 1900 / 2000: loss 8.996743
# (49000,)
# training accuracy: 0.390041
# (1000,)
# validation accuracy: 0.391000
# (49000, 165)
# iteration 0 / 2000: loss 9.009749
# iteration 100 / 2000: loss 9.000055
# iteration 200 / 2000: loss 8.997151
# iteration 300 / 2000: loss 8.997399
# iteration 400 / 2000: loss 9.001649
# iteration 500 / 2000: loss 8.996262
# iteration 600 / 2000: loss 8.999358
# iteration 700 / 2000: loss 8.998522
# iteration 800 / 2000: loss 8.996129
# iteration 900 / 2000: loss 8.998318
# iteration 1000 / 2000: loss 8.996947
# iteration 1100 / 2000: loss 8.996991
# iteration 1200 / 2000: loss 8.996691
# iteration 1300 / 2000: loss 8.996986
# iteration 1400 / 2000: loss 8.997330
# iteration 1500 / 2000: loss 8.996962
# iteration 1600 / 2000: loss 8.997353
# iteration 1700 / 2000: loss 8.997001
# iteration 1800 / 2000: loss 8.997459
# iteration 1900 / 2000: loss 8.997271
# (49000,)
# training accuracy: 0.391490
# (1000,)
# validation accuracy: 0.375000
# (49000, 165)
# iteration 0 / 2000: loss 9.005082
# iteration 100 / 2000: loss 9.018392
# iteration 200 / 2000: loss 9.006779
# iteration 300 / 2000: loss 9.009089
# iteration 400 / 2000: loss 9.006036
# iteration 500 / 2000: loss 9.001942
# iteration 600 / 2000: loss 9.001161
# iteration 700 / 2000: loss 9.000734
# iteration 800 / 2000: loss 9.002330
# iteration 900 / 2000: loss 9.000859
# iteration 1000 / 2000: loss 8.998330
# iteration 1100 / 2000: loss 8.998223
# iteration 1200 / 2000: loss 8.997689
# iteration 1300 / 2000: loss 8.998050
# iteration 1400 / 2000: loss 8.997987
# iteration 1500 / 2000: loss 8.997383
# iteration 1600 / 2000: loss 8.997324
# iteration 1700 / 2000: loss 8.997046
# iteration 1800 / 2000: loss 8.996912
# iteration 1900 / 2000: loss 8.997126
# (49000,)
# training accuracy: 0.398020
# (1000,)
# validation accuracy: 0.403000
# (49000, 165)
# iteration 0 / 2000: loss 8.985692
# iteration 100 / 2000: loss 8.996897
# iteration 200 / 2000: loss 9.002834
# iteration 300 / 2000: loss 9.001065
# iteration 400 / 2000: loss 8.995750
# iteration 500 / 2000: loss 8.999100
# iteration 600 / 2000: loss 8.997704
# iteration 700 / 2000: loss 8.994396
# iteration 800 / 2000: loss 8.994774
# iteration 900 / 2000: loss 8.996267
# iteration 1000 / 2000: loss 8.997485
# iteration 1100 / 2000: loss 8.996268
# iteration 1200 / 2000: loss 8.996316
# iteration 1300 / 2000: loss 8.997193
# iteration 1400 / 2000: loss 8.996702
# iteration 1500 / 2000: loss 8.997311
# iteration 1600 / 2000: loss 8.996904
# iteration 1700 / 2000: loss 8.996902
# iteration 1800 / 2000: loss 8.996794
# iteration 1900 / 2000: loss 8.997331
# (49000,)
# training accuracy: 0.376755
# (1000,)
# validation accuracy: 0.405000
# (49000, 165)
# iteration 0 / 2000: loss 8.988671
# iteration 100 / 2000: loss 9.004922
# iteration 200 / 2000: loss 8.997451
# iteration 300 / 2000: loss 8.997289
# iteration 400 / 2000: loss 8.998932
# iteration 500 / 2000: loss 8.998887
# iteration 600 / 2000: loss 8.998817
# iteration 700 / 2000: loss 9.000023
# iteration 800 / 2000: loss 8.996855
# iteration 900 / 2000: loss 8.997421
# iteration 1000 / 2000: loss 8.998044
# iteration 1100 / 2000: loss 8.997241
# iteration 1200 / 2000: loss 8.996769
# iteration 1300 / 2000: loss 8.996447
# iteration 1400 / 2000: loss 8.996735
# iteration 1500 / 2000: loss 8.997325
# iteration 1600 / 2000: loss 8.997173
# iteration 1700 / 2000: loss 8.996574
# iteration 1800 / 2000: loss 8.996959
# iteration 1900 / 2000: loss 8.996842
# (49000,)
# training accuracy: 0.390592
# (1000,)
# validation accuracy: 0.409000
# (49000, 165)
# iteration 0 / 2000: loss 8.997977
# iteration 100 / 2000: loss 8.986101
# iteration 200 / 2000: loss 8.994190
# iteration 300 / 2000: loss 8.995789
# iteration 400 / 2000: loss 8.995691
# iteration 500 / 2000: loss 8.997438
# iteration 600 / 2000: loss 8.999329
# iteration 700 / 2000: loss 8.994771
# iteration 800 / 2000: loss 8.997841
# iteration 900 / 2000: loss 8.996514
# iteration 1000 / 2000: loss 8.996556
# iteration 1100 / 2000: loss 8.996554
# iteration 1200 / 2000: loss 8.996743
# iteration 1300 / 2000: loss 8.996733
# iteration 1400 / 2000: loss 8.996529
# iteration 1500 / 2000: loss 8.996850
# iteration 1600 / 2000: loss 8.997035
# iteration 1700 / 2000: loss 8.997438
# iteration 1800 / 2000: loss 8.997127
# iteration 1900 / 2000: loss 8.996795
# (49000,)
# training accuracy: 0.390714
# (1000,)
# validation accuracy: 0.391000
# (49000, 165)
# iteration 0 / 2000: loss 8.989239
# iteration 100 / 2000: loss 8.984691
# iteration 200 / 2000: loss 8.992455
# iteration 300 / 2000: loss 8.994631
# iteration 400 / 2000: loss 8.988242
# iteration 500 / 2000: loss 8.991320
# iteration 600 / 2000: loss 8.992043
# iteration 700 / 2000: loss 8.997270
# iteration 800 / 2000: loss 8.994759
# iteration 900 / 2000: loss 8.995489
# iteration 1000 / 2000: loss 8.996003
# iteration 1100 / 2000: loss 8.996088
# iteration 1200 / 2000: loss 8.996722
# iteration 1300 / 2000: loss 8.996897
# iteration 1400 / 2000: loss 8.996427
# iteration 1500 / 2000: loss 8.996768
# iteration 1600 / 2000: loss 8.997094
# iteration 1700 / 2000: loss 8.996939
# iteration 1800 / 2000: loss 8.997112
# iteration 1900 / 2000: loss 8.997106
# (49000,)
# training accuracy: 0.387367
# (1000,)
# validation accuracy: 0.385000
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 175)
# iteration 0 / 2000: loss 8.993757
# iteration 100 / 2000: loss 9.000317
# iteration 200 / 2000: loss 9.004621
# iteration 300 / 2000: loss 9.005115
# iteration 400 / 2000: loss 8.998480
# iteration 500 / 2000: loss 9.000246
# iteration 600 / 2000: loss 8.999220
# iteration 700 / 2000: loss 8.997370
# iteration 800 / 2000: loss 8.998285
# iteration 900 / 2000: loss 8.997593
# iteration 1000 / 2000: loss 8.998002
# iteration 1100 / 2000: loss 8.997878
# iteration 1200 / 2000: loss 8.997167
# iteration 1300 / 2000: loss 8.997065
# iteration 1400 / 2000: loss 8.997198
# iteration 1500 / 2000: loss 8.996916
# iteration 1600 / 2000: loss 8.996903
# iteration 1700 / 2000: loss 8.997031
# iteration 1800 / 2000: loss 8.997020
# iteration 1900 / 2000: loss 8.996879
# (49000,)
# training accuracy: 0.390857
# (1000,)
# validation accuracy: 0.403000
# (49000, 175)
# iteration 0 / 2000: loss 8.988994
# iteration 100 / 2000: loss 8.995516
# iteration 200 / 2000: loss 8.990600
# iteration 300 / 2000: loss 8.988028
# iteration 400 / 2000: loss 8.988203
# iteration 500 / 2000: loss 8.995591
# iteration 600 / 2000: loss 8.993850
# iteration 700 / 2000: loss 8.996231
# iteration 800 / 2000: loss 8.995318
# iteration 900 / 2000: loss 8.994229
# iteration 1000 / 2000: loss 8.995497
# iteration 1100 / 2000: loss 8.996733
# iteration 1200 / 2000: loss 8.996084
# iteration 1300 / 2000: loss 8.996866
# iteration 1400 / 2000: loss 8.996304
# iteration 1500 / 2000: loss 8.996601
# iteration 1600 / 2000: loss 8.996695
# iteration 1700 / 2000: loss 8.996816
# iteration 1800 / 2000: loss 8.996780
# iteration 1900 / 2000: loss 8.996746
# (49000,)
# training accuracy: 0.396245
# (1000,)
# validation accuracy: 0.406000
# (49000, 175)
# iteration 0 / 2000: loss 8.972233
# iteration 100 / 2000: loss 8.980337
# iteration 200 / 2000: loss 8.985310
# iteration 300 / 2000: loss 8.988054
# iteration 400 / 2000: loss 8.987925
# iteration 500 / 2000: loss 8.994291
# iteration 600 / 2000: loss 8.990362
# iteration 700 / 2000: loss 8.993309
# iteration 800 / 2000: loss 8.996982
# iteration 900 / 2000: loss 8.996240
# iteration 1000 / 2000: loss 8.994789
# iteration 1100 / 2000: loss 8.996241
# iteration 1200 / 2000: loss 8.996263
# iteration 1300 / 2000: loss 8.996488
# iteration 1400 / 2000: loss 8.996650
# iteration 1500 / 2000: loss 8.996911
# iteration 1600 / 2000: loss 8.996512
# iteration 1700 / 2000: loss 8.996699
# iteration 1800 / 2000: loss 8.996796
# iteration 1900 / 2000: loss 8.996906
# (49000,)
# training accuracy: 0.389327
# (1000,)
# validation accuracy: 0.375000
# (49000, 175)
# iteration 0 / 2000: loss 9.003979
# iteration 100 / 2000: loss 9.010336
# iteration 200 / 2000: loss 9.005943
# iteration 300 / 2000: loss 8.990271
# iteration 400 / 2000: loss 8.995996
# iteration 500 / 2000: loss 8.992661
# iteration 600 / 2000: loss 8.997441
# iteration 700 / 2000: loss 8.997721
# iteration 800 / 2000: loss 8.997331
# iteration 900 / 2000: loss 8.997227
# iteration 1000 / 2000: loss 8.996379
# iteration 1100 / 2000: loss 8.997122
# iteration 1200 / 2000: loss 8.997117
# iteration 1300 / 2000: loss 8.997416
# iteration 1400 / 2000: loss 8.996796
# iteration 1500 / 2000: loss 8.997509
# iteration 1600 / 2000: loss 8.997394
# iteration 1700 / 2000: loss 8.997046
# iteration 1800 / 2000: loss 8.997000
# iteration 1900 / 2000: loss 8.996905
# (49000,)
# training accuracy: 0.391143
# (1000,)
# validation accuracy: 0.400000
# (49000, 175)
# iteration 0 / 2000: loss 8.989759
# iteration 100 / 2000: loss 8.996632
# iteration 200 / 2000: loss 9.000860
# iteration 300 / 2000: loss 9.000637
# iteration 400 / 2000: loss 8.996917
# iteration 500 / 2000: loss 8.995998
# iteration 600 / 2000: loss 8.994200
# iteration 700 / 2000: loss 8.998401
# iteration 800 / 2000: loss 8.997167
# iteration 900 / 2000: loss 8.995697
# iteration 1000 / 2000: loss 8.998400
# iteration 1100 / 2000: loss 8.996373
# iteration 1200 / 2000: loss 8.996689
# iteration 1300 / 2000: loss 8.996929
# iteration 1400 / 2000: loss 8.997810
# iteration 1500 / 2000: loss 8.996626
# iteration 1600 / 2000: loss 8.996769
# iteration 1700 / 2000: loss 8.996849
# iteration 1800 / 2000: loss 8.997196
# iteration 1900 / 2000: loss 8.997101
# (49000,)
# training accuracy: 0.399898
# (1000,)
# validation accuracy: 0.415000
# (49000, 175)
# iteration 0 / 2000: loss 9.003041
# iteration 100 / 2000: loss 8.999565
# iteration 200 / 2000: loss 8.993841
# iteration 300 / 2000: loss 8.992717
# iteration 400 / 2000: loss 8.999199
# iteration 500 / 2000: loss 8.998546
# iteration 600 / 2000: loss 8.995223
# iteration 700 / 2000: loss 8.998387
# iteration 800 / 2000: loss 8.996935
# iteration 900 / 2000: loss 8.997594
# iteration 1000 / 2000: loss 8.997067
# iteration 1100 / 2000: loss 8.997690
# iteration 1200 / 2000: loss 8.997166
# iteration 1300 / 2000: loss 8.997104
# iteration 1400 / 2000: loss 8.996546
# iteration 1500 / 2000: loss 8.997222
# iteration 1600 / 2000: loss 8.997241
# iteration 1700 / 2000: loss 8.997142
# iteration 1800 / 2000: loss 8.996872
# iteration 1900 / 2000: loss 8.997086
# (49000,)
# training accuracy: 0.397694
# (1000,)
# validation accuracy: 0.405000
# (49000, 175)
# iteration 0 / 2000: loss 9.021694
# iteration 100 / 2000: loss 9.002920
# iteration 200 / 2000: loss 9.001520
# iteration 300 / 2000: loss 9.003748
# iteration 400 / 2000: loss 9.005478
# iteration 500 / 2000: loss 9.004637
# iteration 600 / 2000: loss 8.995160
# iteration 700 / 2000: loss 8.997075
# iteration 800 / 2000: loss 8.996903
# iteration 900 / 2000: loss 8.998861
# iteration 1000 / 2000: loss 8.998187
# iteration 1100 / 2000: loss 8.996917
# iteration 1200 / 2000: loss 8.997723
# iteration 1300 / 2000: loss 8.997253
# iteration 1400 / 2000: loss 8.997249
# iteration 1500 / 2000: loss 8.996984
# iteration 1600 / 2000: loss 8.997174
# iteration 1700 / 2000: loss 8.996921
# iteration 1800 / 2000: loss 8.997113
# iteration 1900 / 2000: loss 8.996962
# (49000,)
# training accuracy: 0.386673
# (1000,)
# validation accuracy: 0.394000
# (49000, 175)
# iteration 0 / 2000: loss 8.997016
# iteration 100 / 2000: loss 9.002260
# iteration 200 / 2000: loss 9.000100
# iteration 300 / 2000: loss 8.992832
# iteration 400 / 2000: loss 8.994165
# iteration 500 / 2000: loss 8.994944
# iteration 600 / 2000: loss 8.996870
# iteration 700 / 2000: loss 8.996594
# iteration 800 / 2000: loss 8.996158
# iteration 900 / 2000: loss 8.996496
# iteration 1000 / 2000: loss 8.996271
# iteration 1100 / 2000: loss 8.996698
# iteration 1200 / 2000: loss 8.998454
# iteration 1300 / 2000: loss 8.996950
# iteration 1400 / 2000: loss 8.997386
# iteration 1500 / 2000: loss 8.996804
# iteration 1600 / 2000: loss 8.997183
# iteration 1700 / 2000: loss 8.996849
# iteration 1800 / 2000: loss 8.996480
# iteration 1900 / 2000: loss 8.997134
# (49000,)
# training accuracy: 0.383878
# (1000,)
# validation accuracy: 0.389000
# (49000, 175)
# iteration 0 / 2000: loss 8.993476
# iteration 100 / 2000: loss 8.999936
# iteration 200 / 2000: loss 9.004066
# iteration 300 / 2000: loss 9.002489
# iteration 400 / 2000: loss 8.995476
# iteration 500 / 2000: loss 9.000005
# iteration 600 / 2000: loss 8.997588
# iteration 700 / 2000: loss 8.999286
# iteration 800 / 2000: loss 8.997945
# iteration 900 / 2000: loss 8.997682
# iteration 1000 / 2000: loss 8.997451
# iteration 1100 / 2000: loss 8.996580
# iteration 1200 / 2000: loss 8.997289
# iteration 1300 / 2000: loss 8.997175
# iteration 1400 / 2000: loss 8.997101
# iteration 1500 / 2000: loss 8.997116
# iteration 1600 / 2000: loss 8.996663
# iteration 1700 / 2000: loss 8.997100
# iteration 1800 / 2000: loss 8.996704
# iteration 1900 / 2000: loss 8.996730
# (49000,)
# training accuracy: 0.393755
# (1000,)
# validation accuracy: 0.402000
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 185)
# iteration 0 / 2000: loss 8.991276
# iteration 100 / 2000: loss 8.989887
# iteration 200 / 2000: loss 8.986952
# iteration 300 / 2000: loss 8.993729
# iteration 400 / 2000: loss 8.989623
# iteration 500 / 2000: loss 8.994822
# iteration 600 / 2000: loss 8.995858
# iteration 700 / 2000: loss 8.995556
# iteration 800 / 2000: loss 8.996019
# iteration 900 / 2000: loss 8.995308
# iteration 1000 / 2000: loss 8.995526
# iteration 1100 / 2000: loss 8.995480
# iteration 1200 / 2000: loss 8.996395
# iteration 1300 / 2000: loss 8.996014
# iteration 1400 / 2000: loss 8.996604
# iteration 1500 / 2000: loss 8.996716
# iteration 1600 / 2000: loss 8.996324
# iteration 1700 / 2000: loss 8.996750
# iteration 1800 / 2000: loss 8.996443
# iteration 1900 / 2000: loss 8.996640
# (49000,)
# training accuracy: 0.399898
# (1000,)
# validation accuracy: 0.390000
# (49000, 185)
# iteration 0 / 2000: loss 9.004763
# iteration 100 / 2000: loss 8.995264
# iteration 200 / 2000: loss 9.005975
# iteration 300 / 2000: loss 8.994855
# iteration 400 / 2000: loss 8.995821
# iteration 500 / 2000: loss 8.999388
# iteration 600 / 2000: loss 8.995850
# iteration 700 / 2000: loss 8.998354
# iteration 800 / 2000: loss 8.998841
# iteration 900 / 2000: loss 8.996770
# iteration 1000 / 2000: loss 8.996853
# iteration 1100 / 2000: loss 8.996988
# iteration 1200 / 2000: loss 8.996338
# iteration 1300 / 2000: loss 8.997001
# iteration 1400 / 2000: loss 8.996064
# iteration 1500 / 2000: loss 8.996809
# iteration 1600 / 2000: loss 8.996312
# iteration 1700 / 2000: loss 8.996510
# iteration 1800 / 2000: loss 8.997045
# iteration 1900 / 2000: loss 8.997002
# (49000,)
# training accuracy: 0.395388
# (1000,)
# validation accuracy: 0.406000
# (49000, 185)
# iteration 0 / 2000: loss 8.990719
# iteration 100 / 2000: loss 8.990819
# iteration 200 / 2000: loss 9.002168
# iteration 300 / 2000: loss 9.000736
# iteration 400 / 2000: loss 8.994007
# iteration 500 / 2000: loss 8.997637
# iteration 600 / 2000: loss 8.997258
# iteration 700 / 2000: loss 8.995260
# iteration 800 / 2000: loss 8.996888
# iteration 900 / 2000: loss 8.997562
# iteration 1000 / 2000: loss 8.997330
# iteration 1100 / 2000: loss 8.996993
# iteration 1200 / 2000: loss 8.995564
# iteration 1300 / 2000: loss 8.996667
# iteration 1400 / 2000: loss 8.997170
# iteration 1500 / 2000: loss 8.996015
# iteration 1600 / 2000: loss 8.997255
# iteration 1700 / 2000: loss 8.996710
# iteration 1800 / 2000: loss 8.997003
# iteration 1900 / 2000: loss 8.996788
# (49000,)
# training accuracy: 0.395122
# (1000,)
# validation accuracy: 0.401000
# (49000, 185)
# iteration 0 / 2000: loss 9.000126
# iteration 100 / 2000: loss 9.006084
# iteration 200 / 2000: loss 8.996194
# iteration 300 / 2000: loss 9.001250
# iteration 400 / 2000: loss 8.998590
# iteration 500 / 2000: loss 9.001039
# iteration 600 / 2000: loss 8.999037
# iteration 700 / 2000: loss 8.999108
# iteration 800 / 2000: loss 8.998391
# iteration 900 / 2000: loss 8.997457
# iteration 1000 / 2000: loss 8.995973
# iteration 1100 / 2000: loss 8.997496
# iteration 1200 / 2000: loss 8.997814
# iteration 1300 / 2000: loss 8.997651
# iteration 1400 / 2000: loss 8.996950
# iteration 1500 / 2000: loss 8.996622
# iteration 1600 / 2000: loss 8.996613
# iteration 1700 / 2000: loss 8.996999
# iteration 1800 / 2000: loss 8.996749
# iteration 1900 / 2000: loss 8.996355
# (49000,)
# training accuracy: 0.397612
# (1000,)
# validation accuracy: 0.391000
# (49000, 185)
# iteration 0 / 2000: loss 8.983689
# iteration 100 / 2000: loss 9.006741
# iteration 200 / 2000: loss 9.001503
# iteration 300 / 2000: loss 8.988447
# iteration 400 / 2000: loss 8.996932
# iteration 500 / 2000: loss 8.999520
# iteration 600 / 2000: loss 9.000863
# iteration 700 / 2000: loss 8.998002
# iteration 800 / 2000: loss 8.995389
# iteration 900 / 2000: loss 8.996846
# iteration 1000 / 2000: loss 8.997115
# iteration 1100 / 2000: loss 8.997742
# iteration 1200 / 2000: loss 8.996999
# iteration 1300 / 2000: loss 8.997668
# iteration 1400 / 2000: loss 8.997300
# iteration 1500 / 2000: loss 8.997293
# iteration 1600 / 2000: loss 8.996849
# iteration 1700 / 2000: loss 8.996851
# iteration 1800 / 2000: loss 8.996774
# iteration 1900 / 2000: loss 8.997093
# (49000,)
# training accuracy: 0.391449
# (1000,)
# validation accuracy: 0.404000
# (49000, 185)
# iteration 0 / 2000: loss 9.006894
# iteration 100 / 2000: loss 9.009398
# iteration 200 / 2000: loss 9.008847
# iteration 300 / 2000: loss 9.005203
# iteration 400 / 2000: loss 9.008610
# iteration 500 / 2000: loss 8.999481
# iteration 600 / 2000: loss 8.998153
# iteration 700 / 2000: loss 8.997873
# iteration 800 / 2000: loss 8.998053
# iteration 900 / 2000: loss 8.997906
# iteration 1000 / 2000: loss 8.997584
# iteration 1100 / 2000: loss 8.997964
# iteration 1200 / 2000: loss 8.997481
# iteration 1300 / 2000: loss 8.997506
# iteration 1400 / 2000: loss 8.997382
# iteration 1500 / 2000: loss 8.997362
# iteration 1600 / 2000: loss 8.997146
# iteration 1700 / 2000: loss 8.996878
# iteration 1800 / 2000: loss 8.996827
# iteration 1900 / 2000: loss 8.997158
# (49000,)
# training accuracy: 0.394612
# (1000,)
# validation accuracy: 0.395000
# (49000, 185)
# iteration 0 / 2000: loss 8.994694
# iteration 100 / 2000: loss 8.988416
# iteration 200 / 2000: loss 9.004025
# iteration 300 / 2000: loss 8.995911
# iteration 400 / 2000: loss 8.999964
# iteration 500 / 2000: loss 9.000865
# iteration 600 / 2000: loss 8.998193
# iteration 700 / 2000: loss 8.996946
# iteration 800 / 2000: loss 8.997829
# iteration 900 / 2000: loss 8.998248
# iteration 1000 / 2000: loss 8.997662
# iteration 1100 / 2000: loss 8.996967
# iteration 1200 / 2000: loss 8.997564
# iteration 1300 / 2000: loss 8.997473
# iteration 1400 / 2000: loss 8.996709
# iteration 1500 / 2000: loss 8.997298
# iteration 1600 / 2000: loss 8.996903
# iteration 1700 / 2000: loss 8.996644
# iteration 1800 / 2000: loss 8.996807
# iteration 1900 / 2000: loss 8.996542
# (49000,)
# training accuracy: 0.402041
# (1000,)
# validation accuracy: 0.382000
# (49000, 185)
# iteration 0 / 2000: loss 9.015819
# iteration 100 / 2000: loss 8.988751
# iteration 200 / 2000: loss 9.011098
# iteration 300 / 2000: loss 9.003054
# iteration 400 / 2000: loss 8.996699
# iteration 500 / 2000: loss 8.994946
# iteration 600 / 2000: loss 8.998865
# iteration 700 / 2000: loss 8.999209
# iteration 800 / 2000: loss 8.998263
# iteration 900 / 2000: loss 8.996809
# iteration 1000 / 2000: loss 8.997835
# iteration 1100 / 2000: loss 8.997454
# iteration 1200 / 2000: loss 8.996982
# iteration 1300 / 2000: loss 8.997147
# iteration 1400 / 2000: loss 8.996791
# iteration 1500 / 2000: loss 8.997259
# iteration 1600 / 2000: loss 8.997090
# iteration 1700 / 2000: loss 8.996814
# iteration 1800 / 2000: loss 8.996640
# iteration 1900 / 2000: loss 8.996688
# (49000,)
# training accuracy: 0.404796
# (1000,)
# validation accuracy: 0.407000
# (49000, 185)
# iteration 0 / 2000: loss 8.984002
# iteration 100 / 2000: loss 8.988048
# iteration 200 / 2000: loss 8.991184
# iteration 300 / 2000: loss 8.995396
# iteration 400 / 2000: loss 8.992162
# iteration 500 / 2000: loss 8.990291
# iteration 600 / 2000: loss 8.994649
# iteration 700 / 2000: loss 8.995475
# iteration 800 / 2000: loss 8.995365
# iteration 900 / 2000: loss 8.995875
# iteration 1000 / 2000: loss 8.996656
# iteration 1100 / 2000: loss 8.996731
# iteration 1200 / 2000: loss 8.995505
# iteration 1300 / 2000: loss 8.996638
# iteration 1400 / 2000: loss 8.997001
# iteration 1500 / 2000: loss 8.996924
# iteration 1600 / 2000: loss 8.997143
# iteration 1700 / 2000: loss 8.996920
# iteration 1800 / 2000: loss 8.996480
# iteration 1900 / 2000: loss 8.996178
# (49000,)
# training accuracy: 0.396571
# (1000,)
# validation accuracy: 0.406000
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 195)
# iteration 0 / 2000: loss 8.976855
# iteration 100 / 2000: loss 8.980267
# iteration 200 / 2000: loss 8.978064
# iteration 300 / 2000: loss 8.985359
# iteration 400 / 2000: loss 8.983029
# iteration 500 / 2000: loss 8.994847
# iteration 600 / 2000: loss 8.992595
# iteration 700 / 2000: loss 8.993159
# iteration 800 / 2000: loss 8.995629
# iteration 900 / 2000: loss 8.993138
# iteration 1000 / 2000: loss 8.998200
# iteration 1100 / 2000: loss 8.996768
# iteration 1200 / 2000: loss 8.996764
# iteration 1300 / 2000: loss 8.996168
# iteration 1400 / 2000: loss 8.995975
# iteration 1500 / 2000: loss 8.995955
# iteration 1600 / 2000: loss 8.996182
# iteration 1700 / 2000: loss 8.996592
# iteration 1800 / 2000: loss 8.996010
# iteration 1900 / 2000: loss 8.996505
# (49000,)
# training accuracy: 0.396633
# (1000,)
# validation accuracy: 0.401000
# (49000, 195)
# iteration 0 / 2000: loss 8.998315
# iteration 100 / 2000: loss 9.004946
# iteration 200 / 2000: loss 8.996700
# iteration 300 / 2000: loss 9.000259
# iteration 400 / 2000: loss 9.004951
# iteration 500 / 2000: loss 8.998825
# iteration 600 / 2000: loss 8.996700
# iteration 700 / 2000: loss 9.001636
# iteration 800 / 2000: loss 8.996606
# iteration 900 / 2000: loss 8.996913
# iteration 1000 / 2000: loss 8.997186
# iteration 1100 / 2000: loss 8.997955
# iteration 1200 / 2000: loss 8.996803
# iteration 1300 / 2000: loss 8.996980
# iteration 1400 / 2000: loss 8.996957
# iteration 1500 / 2000: loss 8.996949
# iteration 1600 / 2000: loss 8.997251
# iteration 1700 / 2000: loss 8.996964
# iteration 1800 / 2000: loss 8.996852
# iteration 1900 / 2000: loss 8.996374
# (49000,)
# training accuracy: 0.393449
# (1000,)
# validation accuracy: 0.392000
# (49000, 195)
# iteration 0 / 2000: loss 8.995047
# iteration 100 / 2000: loss 9.000687
# iteration 200 / 2000: loss 9.000810
# iteration 300 / 2000: loss 9.002236
# iteration 400 / 2000: loss 8.995207
# iteration 500 / 2000: loss 8.996264
# iteration 600 / 2000: loss 8.996764
# iteration 700 / 2000: loss 8.993666
# iteration 800 / 2000: loss 8.997833
# iteration 900 / 2000: loss 8.996561
# iteration 1000 / 2000: loss 8.997128
# iteration 1100 / 2000: loss 8.994448
# iteration 1200 / 2000: loss 8.996579
# iteration 1300 / 2000: loss 8.996235
# iteration 1400 / 2000: loss 8.997133
# iteration 1500 / 2000: loss 8.997040
# iteration 1600 / 2000: loss 8.996834
# iteration 1700 / 2000: loss 8.996173
# iteration 1800 / 2000: loss 8.996436
# iteration 1900 / 2000: loss 8.996268
# (49000,)
# training accuracy: 0.393714
# (1000,)
# validation accuracy: 0.377000
# (49000, 195)
# iteration 0 / 2000: loss 9.011388
# iteration 100 / 2000: loss 8.996859
# iteration 200 / 2000: loss 9.006672
# iteration 300 / 2000: loss 9.006513
# iteration 400 / 2000: loss 9.003044
# iteration 500 / 2000: loss 9.002381
# iteration 600 / 2000: loss 9.000686
# iteration 700 / 2000: loss 8.999751
# iteration 800 / 2000: loss 9.000948
# iteration 900 / 2000: loss 8.997861
# iteration 1000 / 2000: loss 8.997276
# iteration 1100 / 2000: loss 8.997681
# iteration 1200 / 2000: loss 8.997784
# iteration 1300 / 2000: loss 8.997366
# iteration 1400 / 2000: loss 8.997859
# iteration 1500 / 2000: loss 8.996654
# iteration 1600 / 2000: loss 8.996848
# iteration 1700 / 2000: loss 8.997028
# iteration 1800 / 2000: loss 8.996462
# iteration 1900 / 2000: loss 8.996777
# (49000,)
# training accuracy: 0.392816
# (1000,)
# validation accuracy: 0.403000
# (49000, 195)
# iteration 0 / 2000: loss 9.015316
# iteration 100 / 2000: loss 9.017063
# iteration 200 / 2000: loss 9.009212
# iteration 300 / 2000: loss 9.009396
# iteration 400 / 2000: loss 9.013102
# iteration 500 / 2000: loss 8.999394
# iteration 600 / 2000: loss 9.002676
# iteration 700 / 2000: loss 8.998895
# iteration 800 / 2000: loss 8.999833
# iteration 900 / 2000: loss 8.999697
# iteration 1000 / 2000: loss 8.997191
# iteration 1100 / 2000: loss 8.996713
# iteration 1200 / 2000: loss 8.998083
# iteration 1300 / 2000: loss 8.997275
# iteration 1400 / 2000: loss 8.997185
# iteration 1500 / 2000: loss 8.997479
# iteration 1600 / 2000: loss 8.997219
# iteration 1700 / 2000: loss 8.996773
# iteration 1800 / 2000: loss 8.996705
# iteration 1900 / 2000: loss 8.997005
# (49000,)
# training accuracy: 0.396551
# (1000,)
# validation accuracy: 0.415000
# (49000, 195)
# iteration 0 / 2000: loss 8.999437
# iteration 100 / 2000: loss 8.997951
# iteration 200 / 2000: loss 8.983640
# iteration 300 / 2000: loss 8.995518
# iteration 400 / 2000: loss 8.995517
# iteration 500 / 2000: loss 8.993506
# iteration 600 / 2000: loss 8.995196
# iteration 700 / 2000: loss 8.994406
# iteration 800 / 2000: loss 8.995645
# iteration 900 / 2000: loss 8.994706
# iteration 1000 / 2000: loss 8.996465
# iteration 1100 / 2000: loss 8.996677
# iteration 1200 / 2000: loss 8.996858
# iteration 1300 / 2000: loss 8.995419
# iteration 1400 / 2000: loss 8.996114
# iteration 1500 / 2000: loss 8.996161
# iteration 1600 / 2000: loss 8.997141
# iteration 1700 / 2000: loss 8.996584
# iteration 1800 / 2000: loss 8.996927
# iteration 1900 / 2000: loss 8.996064
# (49000,)
# training accuracy: 0.396286
# (1000,)
# validation accuracy: 0.375000
# (49000, 195)
# iteration 0 / 2000: loss 8.999842
# iteration 100 / 2000: loss 8.983552
# iteration 200 / 2000: loss 8.993897
# iteration 300 / 2000: loss 9.001084
# iteration 400 / 2000: loss 8.994205
# iteration 500 / 2000: loss 8.994052
# iteration 600 / 2000: loss 8.997149
# iteration 700 / 2000: loss 8.995965
# iteration 800 / 2000: loss 8.995218
# iteration 900 / 2000: loss 8.996971
# iteration 1000 / 2000: loss 8.996563
# iteration 1100 / 2000: loss 8.996428
# iteration 1200 / 2000: loss 8.997149
# iteration 1300 / 2000: loss 8.996422
# iteration 1400 / 2000: loss 8.996125
# iteration 1500 / 2000: loss 8.996765
# iteration 1600 / 2000: loss 8.996335
# iteration 1700 / 2000: loss 8.996525
# iteration 1800 / 2000: loss 8.996647
# iteration 1900 / 2000: loss 8.996521
# (49000,)
# training accuracy: 0.399959
# (1000,)
# validation accuracy: 0.419000
# (49000, 195)
# iteration 0 / 2000: loss 9.019594
# iteration 100 / 2000: loss 9.013788
# iteration 200 / 2000: loss 9.012646
# iteration 300 / 2000: loss 9.001284
# iteration 400 / 2000: loss 8.999292
# iteration 500 / 2000: loss 9.006056
# iteration 600 / 2000: loss 9.001818
# iteration 700 / 2000: loss 8.998530
# iteration 800 / 2000: loss 8.998901
# iteration 900 / 2000: loss 8.997744
# iteration 1000 / 2000: loss 8.999527
# iteration 1100 / 2000: loss 8.997910
# iteration 1200 / 2000: loss 8.997423
# iteration 1300 / 2000: loss 8.996964
# iteration 1400 / 2000: loss 8.997579
# iteration 1500 / 2000: loss 8.997351
# iteration 1600 / 2000: loss 8.997001
# iteration 1700 / 2000: loss 8.996486
# iteration 1800 / 2000: loss 8.996763
# iteration 1900 / 2000: loss 8.996729
# (49000,)
# training accuracy: 0.390980
# (1000,)
# validation accuracy: 0.407000
# (49000, 195)
# iteration 0 / 2000: loss 9.006203
# iteration 100 / 2000: loss 9.011878
# iteration 200 / 2000: loss 9.002872
# iteration 300 / 2000: loss 8.997194
# iteration 400 / 2000: loss 8.993837
# iteration 500 / 2000: loss 9.000650
# iteration 600 / 2000: loss 8.997715
# iteration 700 / 2000: loss 8.999470
# iteration 800 / 2000: loss 8.999960
# iteration 900 / 2000: loss 8.998061
# iteration 1000 / 2000: loss 8.997710
# iteration 1100 / 2000: loss 8.997380
# iteration 1200 / 2000: loss 8.997821
# iteration 1300 / 2000: loss 8.996497
# iteration 1400 / 2000: loss 8.997068
# iteration 1500 / 2000: loss 8.996620
# iteration 1600 / 2000: loss 8.996914
# iteration 1700 / 2000: loss 8.996923
# iteration 1800 / 2000: loss 8.996776
# iteration 1900 / 2000: loss 8.996751
# (49000,)
# training accuracy: 0.399286
# (1000,)
# validation accuracy: 0.398000
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 205)
# iteration 0 / 2000: loss 9.012961
# iteration 100 / 2000: loss 8.996836
# iteration 200 / 2000: loss 9.000019
# iteration 300 / 2000: loss 9.007566
# iteration 400 / 2000: loss 9.000653
# iteration 500 / 2000: loss 9.002230
# iteration 600 / 2000: loss 8.998935
# iteration 700 / 2000: loss 8.999635
# iteration 800 / 2000: loss 8.997968
# iteration 900 / 2000: loss 8.997141
# iteration 1000 / 2000: loss 8.996768
# iteration 1100 / 2000: loss 8.997054
# iteration 1200 / 2000: loss 8.996528
# iteration 1300 / 2000: loss 8.995795
# iteration 1400 / 2000: loss 8.996031
# iteration 1500 / 2000: loss 8.996315
# iteration 1600 / 2000: loss 8.996531
# iteration 1700 / 2000: loss 8.996759
# iteration 1800 / 2000: loss 8.996906
# iteration 1900 / 2000: loss 8.996351
# (49000,)
# training accuracy: 0.395000
# (1000,)
# validation accuracy: 0.400000
# (49000, 205)
# iteration 0 / 2000: loss 8.994430
# iteration 100 / 2000: loss 9.012524
# iteration 200 / 2000: loss 9.007735
# iteration 300 / 2000: loss 9.006821
# iteration 400 / 2000: loss 9.000595
# iteration 500 / 2000: loss 9.000023
# iteration 600 / 2000: loss 8.998837
# iteration 700 / 2000: loss 8.997557
# iteration 800 / 2000: loss 8.998430
# iteration 900 / 2000: loss 8.999309
# iteration 1000 / 2000: loss 8.997772
# iteration 1100 / 2000: loss 8.997044
# iteration 1200 / 2000: loss 8.996059
# iteration 1300 / 2000: loss 8.996446
# iteration 1400 / 2000: loss 8.996950
# iteration 1500 / 2000: loss 8.997228
# iteration 1600 / 2000: loss 8.997037
# iteration 1700 / 2000: loss 8.996880
# iteration 1800 / 2000: loss 8.996456
# iteration 1900 / 2000: loss 8.996665
# (49000,)
# training accuracy: 0.387898
# (1000,)
# validation accuracy: 0.384000
# (49000, 205)
# iteration 0 / 2000: loss 9.025873
# iteration 100 / 2000: loss 8.997247
# iteration 200 / 2000: loss 9.008629
# iteration 300 / 2000: loss 9.003465
# iteration 400 / 2000: loss 8.998168
# iteration 500 / 2000: loss 9.005128
# iteration 600 / 2000: loss 8.999972
# iteration 700 / 2000: loss 8.999179
# iteration 800 / 2000: loss 8.998405
# iteration 900 / 2000: loss 9.000498
# iteration 1000 / 2000: loss 8.997353
# iteration 1100 / 2000: loss 8.997846
# iteration 1200 / 2000: loss 8.997846
# iteration 1300 / 2000: loss 8.996208
# iteration 1400 / 2000: loss 8.997391
# iteration 1500 / 2000: loss 8.996618
# iteration 1600 / 2000: loss 8.996906
# iteration 1700 / 2000: loss 8.996417
# iteration 1800 / 2000: loss 8.996321
# iteration 1900 / 2000: loss 8.996894
# (49000,)
# training accuracy: 0.399735
# (1000,)
# validation accuracy: 0.427000
# (49000, 205)
# iteration 0 / 2000: loss 8.990719
# iteration 100 / 2000: loss 8.993878
# iteration 200 / 2000: loss 9.006457
# iteration 300 / 2000: loss 8.989218
# iteration 400 / 2000: loss 8.994260
# iteration 500 / 2000: loss 8.993821
# iteration 600 / 2000: loss 8.995723
# iteration 700 / 2000: loss 8.995073
# iteration 800 / 2000: loss 8.995796
# iteration 900 / 2000: loss 8.995358
# iteration 1000 / 2000: loss 8.994715
# iteration 1100 / 2000: loss 8.995990
# iteration 1200 / 2000: loss 8.996490
# iteration 1300 / 2000: loss 8.996403
# iteration 1400 / 2000: loss 8.996830
# iteration 1500 / 2000: loss 8.996319
# iteration 1600 / 2000: loss 8.996551
# iteration 1700 / 2000: loss 8.996562
# iteration 1800 / 2000: loss 8.996710
# iteration 1900 / 2000: loss 8.996612
# (49000,)
# training accuracy: 0.390041
# (1000,)
# validation accuracy: 0.379000
# (49000, 205)
# iteration 0 / 2000: loss 8.995232
# iteration 100 / 2000: loss 9.001725
# iteration 200 / 2000: loss 8.997813
# iteration 300 / 2000: loss 9.002736
# iteration 400 / 2000: loss 8.997428
# iteration 500 / 2000: loss 8.991944
# iteration 600 / 2000: loss 8.997367
# iteration 700 / 2000: loss 8.995741
# iteration 800 / 2000: loss 8.998204
# iteration 900 / 2000: loss 8.997552
# iteration 1000 / 2000: loss 8.995310
# iteration 1100 / 2000: loss 8.996262
# iteration 1200 / 2000: loss 8.996267
# iteration 1300 / 2000: loss 8.996239
# iteration 1400 / 2000: loss 8.996217
# iteration 1500 / 2000: loss 8.996722
# iteration 1600 / 2000: loss 8.996435
# iteration 1700 / 2000: loss 8.996650
# iteration 1800 / 2000: loss 8.996104
# iteration 1900 / 2000: loss 8.996636
# (49000,)
# training accuracy: 0.397980
# (1000,)
# validation accuracy: 0.408000
# (49000, 205)
# iteration 0 / 2000: loss 8.999925
# iteration 100 / 2000: loss 8.995347
# iteration 200 / 2000: loss 8.989747
# iteration 300 / 2000: loss 8.997366
# iteration 400 / 2000: loss 8.991367
# iteration 500 / 2000: loss 8.995419
# iteration 600 / 2000: loss 8.996209
# iteration 700 / 2000: loss 8.993472
# iteration 800 / 2000: loss 8.996410
# iteration 900 / 2000: loss 8.995824
# iteration 1000 / 2000: loss 8.997024
# iteration 1100 / 2000: loss 8.997198
# iteration 1200 / 2000: loss 8.996133
# iteration 1300 / 2000: loss 8.997130
# iteration 1400 / 2000: loss 8.996671
# iteration 1500 / 2000: loss 8.996104
# iteration 1600 / 2000: loss 8.996125
# iteration 1700 / 2000: loss 8.996397
# iteration 1800 / 2000: loss 8.996144
# iteration 1900 / 2000: loss 8.995939
# (49000,)
# training accuracy: 0.389429
# (1000,)
# validation accuracy: 0.381000
# (49000, 205)
# iteration 0 / 2000: loss 8.991869
# iteration 100 / 2000: loss 9.005510
# iteration 200 / 2000: loss 9.002341
# iteration 300 / 2000: loss 9.006350
# iteration 400 / 2000: loss 9.007076
# iteration 500 / 2000: loss 9.001306
# iteration 600 / 2000: loss 8.998953
# iteration 700 / 2000: loss 9.000573
# iteration 800 / 2000: loss 8.998353
# iteration 900 / 2000: loss 8.998223
# iteration 1000 / 2000: loss 8.998255
# iteration 1100 / 2000: loss 8.997767
# iteration 1200 / 2000: loss 8.996673
# iteration 1300 / 2000: loss 8.997246
# iteration 1400 / 2000: loss 8.997452
# iteration 1500 / 2000: loss 8.996814
# iteration 1600 / 2000: loss 8.996896
# iteration 1700 / 2000: loss 8.996584
# iteration 1800 / 2000: loss 8.996538
# iteration 1900 / 2000: loss 8.996657
# (49000,)
# training accuracy: 0.394592
# (1000,)
# validation accuracy: 0.387000
# (49000, 205)
# iteration 0 / 2000: loss 9.023655
# iteration 100 / 2000: loss 9.009987
# iteration 200 / 2000: loss 9.003446
# iteration 300 / 2000: loss 9.006134
# iteration 400 / 2000: loss 8.998987
# iteration 500 / 2000: loss 9.001676
# iteration 600 / 2000: loss 8.999596
# iteration 700 / 2000: loss 8.997404
# iteration 800 / 2000: loss 8.998818
# iteration 900 / 2000: loss 8.996659
# iteration 1000 / 2000: loss 8.998069
# iteration 1100 / 2000: loss 8.997098
# iteration 1200 / 2000: loss 8.997299
# iteration 1300 / 2000: loss 8.997224
# iteration 1400 / 2000: loss 8.997268
# iteration 1500 / 2000: loss 8.996781
# iteration 1600 / 2000: loss 8.996518
# iteration 1700 / 2000: loss 8.996567
# iteration 1800 / 2000: loss 8.997078
# iteration 1900 / 2000: loss 8.996847
# (49000,)
# training accuracy: 0.394041
# (1000,)
# validation accuracy: 0.417000
# (49000, 205)
# iteration 0 / 2000: loss 8.982539
# iteration 100 / 2000: loss 8.987752
# iteration 200 / 2000: loss 8.993268
# iteration 300 / 2000: loss 8.991351
# iteration 400 / 2000: loss 8.995200
# iteration 500 / 2000: loss 8.998931
# iteration 600 / 2000: loss 8.997485
# iteration 700 / 2000: loss 8.994593
# iteration 800 / 2000: loss 8.996025
# iteration 900 / 2000: loss 8.996542
# iteration 1000 / 2000: loss 8.996184
# iteration 1100 / 2000: loss 8.996582
# iteration 1200 / 2000: loss 8.996622
# iteration 1300 / 2000: loss 8.996135
# iteration 1400 / 2000: loss 8.996815
# iteration 1500 / 2000: loss 8.996238
# iteration 1600 / 2000: loss 8.996470
# iteration 1700 / 2000: loss 8.996711
# iteration 1800 / 2000: loss 8.996818
# iteration 1900 / 2000: loss 8.996372
# (49000,)
# training accuracy: 0.390837
# (1000,)
# validation accuracy: 0.403000
# nb 1.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.373694 val accuracy: 0.388000
# nb 2.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.392204 val accuracy: 0.384000
# nb 3.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.390857 val accuracy: 0.403000
# nb 4.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.399898 val accuracy: 0.390000
# nb 5.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.396633 val accuracy: 0.401000
# nb 6.000000e+01 lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.395000 val accuracy: 0.400000
# nb 1.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.384245 val accuracy: 0.375000
# nb 2.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.391347 val accuracy: 0.390000
# nb 3.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.396245 val accuracy: 0.406000
# nb 4.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.395388 val accuracy: 0.406000
# nb 5.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.393449 val accuracy: 0.392000
# nb 6.000000e+01 lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.387898 val accuracy: 0.384000
# nb 1.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.388959 val accuracy: 0.371000
# nb 2.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.390041 val accuracy: 0.391000
# nb 3.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.389327 val accuracy: 0.375000
# nb 4.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.395122 val accuracy: 0.401000
# nb 5.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.393714 val accuracy: 0.377000
# nb 6.000000e+01 lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.399735 val accuracy: 0.427000
# nb 1.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.389224 val accuracy: 0.394000
# nb 2.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.391490 val accuracy: 0.375000
# nb 3.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.391143 val accuracy: 0.400000
# nb 4.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.397612 val accuracy: 0.391000
# nb 5.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.392816 val accuracy: 0.403000
# nb 6.000000e+01 lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.390041 val accuracy: 0.379000
# nb 1.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.378612 val accuracy: 0.356000
# nb 2.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.398020 val accuracy: 0.403000
# nb 3.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.399898 val accuracy: 0.415000
# nb 4.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.391449 val accuracy: 0.404000
# nb 5.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.396551 val accuracy: 0.415000
# nb 6.000000e+01 lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.397980 val accuracy: 0.408000
# nb 1.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.386939 val accuracy: 0.400000
# nb 2.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.376755 val accuracy: 0.405000
# nb 3.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.397694 val accuracy: 0.405000
# nb 4.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.394612 val accuracy: 0.395000
# nb 5.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.396286 val accuracy: 0.375000
# nb 6.000000e+01 lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.389429 val accuracy: 0.381000
# nb 1.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.390469 val accuracy: 0.387000
# nb 2.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.390592 val accuracy: 0.409000
# nb 3.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.386673 val accuracy: 0.394000
# nb 4.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.402041 val accuracy: 0.382000
# nb 5.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.399959 val accuracy: 0.419000
# nb 6.000000e+01 lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.394592 val accuracy: 0.387000
# nb 1.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.388020 val accuracy: 0.378000
# nb 2.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.390714 val accuracy: 0.391000
# nb 3.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.383878 val accuracy: 0.389000
# nb 4.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.404796 val accuracy: 0.407000
# nb 5.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.390980 val accuracy: 0.407000
# nb 6.000000e+01 lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.394041 val accuracy: 0.417000
# nb 1.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.379510 val accuracy: 0.367000
# nb 2.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.387367 val accuracy: 0.385000
# nb 3.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.393755 val accuracy: 0.402000
# nb 4.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.396571 val accuracy: 0.406000
# nb 5.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.399286 val accuracy: 0.398000
# nb 6.000000e+01 lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.390837 val accuracy: 0.403000
# best validation accuracy achieved during cross-validation: 0.427000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# (1000,)
# 0.392

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 205)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_hyps = {}

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
lrs = [1e-4, 1e-3, 1e-2]
# regs = np.arange(0, 0.5, 0.1)
bs = 200
ni = 2000
lrs = np.logspace(-10, 0, 5)
regs = np.logspace(-3, 5, 5) 

for reg in regs:
    for lr in lrs:
        print(reg, lr)
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)

        # Train the network
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                    num_iters=ni, batch_size=bs,
                    learning_rate=lr, learning_rate_decay=0.95,
                    reg=reg, verbose=False)
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        print('Validation accuracy: ', val_acc)
        if val_acc > best_val:
            
            best_val = val_acc
            best_net = net
            best_hyps['lr'] = lr
            best_hyps['bs'] = bs
            best_hyps['reg'] = reg
            best_hyps['ni'] = ni

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# 0.001 1e-10
# Validation accuracy:  0.128
# 0.001 3.16227766017e-08
# Validation accuracy:  0.087
# 0.001 1e-05
# Validation accuracy:  0.082
# 0.001 0.00316227766017
# Validation accuracy:  0.089
# 0.001 1.0
# Validation accuracy:  0.586
# 0.1 1e-10
# Validation accuracy:  0.1
# 0.1 3.16227766017e-08
# Validation accuracy:  0.082
# 0.1 1e-05
# Validation accuracy:  0.088
# 0.1 0.00316227766017
# Validation accuracy:  0.105
# 0.1 1.0
# Validation accuracy:  0.379
# 10.0 1e-10
# Validation accuracy:  0.102
# 10.0 3.16227766017e-08
# Validation accuracy:  0.116
# 10.0 1e-05
# Validation accuracy:  0.077
# 10.0 0.00316227766017
# Validation accuracy:  0.113
# 10.0 1.0
# /home/marcin/cs231n/assignment1/cs231n/classifiers/neural_net.py:106: RuntimeWarning: overflow encountered in power
#   XE = np.e ** H
# /home/marcin/cs231n/assignment1/cs231n/classifiers/neural_net.py:110: RuntimeWarning: invalid value encountered in true_divide
#   loss = (-np.log(good_XE / XE_sums)).sum() / X.shape[0] + reg * (np.sum(W1 **2) + np.sum(W2 ** 2))
# /home/marcin/cs231n/assignment1/cs231n/classifiers/neural_net.py:110: RuntimeWarning: divide by zero encountered in log
#   loss = (-np.log(good_XE / XE_sums)).sum() / X.shape[0] + reg * (np.sum(W1 **2) + np.sum(W2 ** 2))
# /home/marcin/cs231n/assignment1/cs231n/classifiers/neural_net.py:125: RuntimeWarning: invalid value encountered in true_divide
#   d_a2 = (-Y  + (XE.T / XE_sums).T)  / z1.shape[0]
# /home/marcin/cs231n/assignment1/cs231n/classifiers/neural_net.py:130: RuntimeWarning: invalid value encountered in greater
#   d_z1 = (d_a2 @ W2.T) * (z1 > 0)
# Validation accuracy:  0.087
# 1000.0 1e-10
# Validation accuracy:  0.09
# 1000.0 3.16227766017e-08
# Validation accuracy:  0.088
# 1000.0 1e-05
# Validation accuracy:  0.087
# 1000.0 0.00316227766017
# Validation accuracy:  0.087
# 1000.0 1.0
# Validation accuracy:  0.087
# 100000.0 1e-10
# Validation accuracy:  0.101
# 100000.0 3.16227766017e-08
# Validation accuracy:  0.078
# 100000.0 1e-05
# Validation accuracy:  0.098
# 100000.0 0.00316227766017
# Validation accuracy:  0.087
# 100000.0 1.0
# Validation accuracy:  0.087

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.596

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
